# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilg50/House_Price_predictions/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The Data
#
# We will be using data from a Kaggle data set:
#
# https://www.kaggle.com/harlfoxem/housesalesprediction
#
# #### Feature Columns
#
# * id - Unique ID for each home sold
# * date - Date of the home sale
# * price - Price of each home sold
# * bedrooms - Number of bedrooms
# * bathrooms - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * sqft_living - Square footage of the apartments interior living space
# * sqft_lot - Square footage of the land space
# * floors - Number of floors
# * waterfront - A dummy variable for whether the apartment was overlooking the waterfront or not
# * view - An index from 0 to 4 of how good the view of the property was
# * condition - An index from 1 to 5 on the condition of the apartment,
# * grade - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * sqft_above - The square footage of the interior housing space that is above ground level
# * sqft_basement - The square footage of the interior housing space that is below ground level
# * yr_built - The year the house was initially built
# * yr_renovated - The year of the house’s last renovation
# * zipcode - What zipcode area the house is in
# * lat - Lattitude
# * long - Longitude
# * sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# * sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
# To check if the data set has any missing values 
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21613.0  4.580302e+09  ...  7.308900e+09  9.900000e+09
# price          21613.0  5.400881e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21613.0  3.370842e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21613.0  2.114757e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21613.0  2.079900e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21613.0  1.510697e+04  ...  1.068800e+04  1.651359e+06
# floors         21613.0  1.494309e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21613.0  7.541757e-03  ...  0.000000e+00  1.000000e+00
# view           21613.0  2.343034e-01  ...  0.000000e+00  4.000000e+00
# condition      21613.0  3.409430e+00  ...  4.000000e+00  5.000000e+00
# grade          21613.0  7.656873e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21613.0  1.788391e+03  ...  2.210000e+03  9.410000e+03
# ...

# %%
df.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
#now let's plot the histogram and pdf of the price column using seaborn
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
 #now let's plot the count of bedrooms
sns.countplot(df['bedrooms'])

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='price', y='sqft_living',data=df )

# %%
plt.figure(figsize=(10,7))
sns.boxenplot(x='bedrooms', y='price',data=df);

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df);

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df);

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# <img src="https://github.com/sahilg50/House_Price_predictions/blob/master/kc_map.gif?raw=1">

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat', data=df, hue='price');
# the plot will look like the king county area

# %%
#Let's clean the map by droping the outliers
df.sort_values('price',ascending=False).head(20)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 7252   6762700020  20141013T000000  ...           3940        8800
# 3914   9808700762  20140611T000000  ...           3930       25449
# 9254   9208900037  20140919T000000  ...           4540       42730
# 4411   2470100110  20140804T000000  ...           3560       24345
# 1448   8907500070  20150413T000000  ...           4600       21750
# 1315   7558700030  20150413T000000  ...           4320       24619
# 1164   1247600105  20141020T000000  ...           3430       26788
# 8092   1924059029  20140617T000000  ...           3270       10454
# 2626   7738500731  20140815T000000  ...           3030       23408
# 8638   3835500195  20140618T000000  ...           3720       14592
# 12370  6065300370  20150506T000000  ...           4740       19329
# 4149   6447300265  20141014T000000  ...           3140       15996
# 2085   8106100105  20141114T000000  ...           4620       22748
# ...

# %%
#Also we see from the probability density function that the house prices are most likely near 0-3 million. so we can remove the rest of the data(outliers).

# %%
# We can remove top 1% of the data based upon the price.
len(df) * 0.01
# Out:
# 216.13

# %%
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat', data=non_top_1_perc, 
                edgecolor=None, alpha=0.2, hue='price', palette="RdYlGn");
# the plot will look like the king county area

# %%
# df = non_top_1_perc

# %%
sns.boxplot(x='waterfront', y='price', data=df)
#  we did this because we see that prices are the highest near waterbodies

# %%
# let's exmaine our features.
df.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
#let's drop the id column because it provides no useful information
df =  df.drop('id', axis=1)
print(len(df.columns))
# Out:
# 20

# %%
df.head()
# Out:
#               date     price  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0  20141013T000000  221900.0         3  ... -122.257           1340        5650
# 1  20141209T000000  538000.0         3  ... -122.319           1690        7639
# 2  20150225T000000  180000.0         2  ... -122.233           2720        8062
# 3  20141209T000000  604000.0         4  ... -122.393           1360        5000
# 4  20150218T000000  510000.0         3  ... -122.045           1800        7503
#
# [5 rows x 20 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         date     price  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0 2014-10-13  221900.0         3  ... -122.257           1340        5650
# 1 2014-12-09  538000.0         3  ... -122.319           1690        7639
# 2 2015-02-25  180000.0         2  ... -122.233           2720        8062
# 3 2014-12-09  604000.0         4  ... -122.393           1360        5000
# 4 2015-02-18  510000.0         3  ... -122.045           1800        7503
#
# [5 rows x 20 columns]

# %%
df['year_sold'] = df['date'].apply(lambda date: date.year)
df['month_sold'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  year_sold  month_sold
# 0 2014-10-13  221900.0         3  ...        5650       2014          10
# 1 2014-12-09  538000.0         3  ...        7639       2014          12
# 2 2015-02-25  180000.0         2  ...        8062       2015           2
# 3 2014-12-09  604000.0         4  ...        5000       2014          12
# 4 2015-02-18  510000.0         3  ...        7503       2015           2
#
# [5 rows x 22 columns]

# %%
# Now we can dropout our date column
df = df.drop('date', axis=1)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month_sold', y='price', data=df)

# %%
df.groupby('month_sold').mean()['price']
# Out:
# month_sold
# 1     525870.889571
# 2     507851.371200
# 3     543977.187200
# 4     561837.774989
# 5     550768.785833
# 6     558002.199541
# 7     544788.764360
# 8     536445.276804
# 9     529253.821871
# 10    539026.971778
# 11    521961.009213
# 12    524461.866757
# Name: price, dtype: float64

# %%
df.groupby('month_sold').mean()['price'].plot()

# %%
df['year_sold'].value_counts()
# Out:
# 2014    14633
# 2015     6980
# Name: year_sold, dtype: int64

# %%
df.groupby('year_sold').mean()['price'].plot()

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year_sold  month_sold
# 0  221900.0         3       1.00  ...        5650       2014          10
# 1  538000.0         3       2.25  ...        7639       2014          12
# 2  180000.0         2       1.00  ...        8062       2015           2
# 3  604000.0         4       3.00  ...        5000       2014          12
# 4  510000.0         3       2.00  ...        7503       2015           2
#
# [5 rows x 21 columns]

# %%
#now there is a column known as zipcode.
#let's see wether the following zipcodes are assigned according to longitude and latitude

sns.scatterplot(x='zipcode', y='long', data=df)

# %%
sns.scatterplot(x='zipcode', y='lat', data=df)

# %%
df.corr()['zipcode'].sort_values()
# Out:
# long            -0.564072
# yr_built        -0.346869
# sqft_living15   -0.279033
# sqft_above      -0.261190
# bathrooms       -0.203866
# sqft_living     -0.199430
# grade           -0.184862
# bedrooms        -0.152668
# sqft_lot15      -0.147221
# sqft_lot        -0.129574
# floors          -0.059121
# price           -0.053203
# month_sold      -0.000171
# year_sold        0.001189
# condition        0.003026
# waterfront       0.030285
# yr_renovated     0.064357
# sqft_basement    0.074845
# view             0.084827
# lat              0.267048
# zipcode          1.000000
# Name: zipcode, dtype: float64

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
# Now we see that there 70 categories of zip code which is too much
# Also the correlation with the price, long, lat is not too much.
# So we will drop this column 

df = df.drop('zipcode', axis=1)

# %%
len(df.columns)
# Out:
# 20

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year_sold  month_sold
# 0  221900.0         3       1.00  ...        5650       2014          10
# 1  538000.0         3       2.25  ...        7639       2014          12
# 2  180000.0         2       1.00  ...        8062       2015           2
# 3  604000.0         4       3.00  ...        5000       2014          12
# 4  510000.0         3       2.00  ...        7503       2015           2
#
# [5 rows x 20 columns]

# %%
# Now let's look at the another column that is yr_renovated
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df.corr()['yr_renovated'].sort_values()
# Out:
# yr_built        -0.224874
# long            -0.068372
# condition       -0.060618
# year_sold       -0.023707
# sqft_living15   -0.002673
# floors           0.006338
# sqft_lot         0.007644
# sqft_lot15       0.007854
# month_sold       0.012827
# grade            0.014414
# bedrooms         0.018841
# sqft_above       0.023285
# lat              0.029398
# bathrooms        0.050739
# sqft_living      0.055363
# sqft_basement    0.071323
# waterfront       0.092885
# view             0.103917
# price            0.126434
# yr_renovated     1.000000
# Name: yr_renovated, dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='yr_built', y='price', data=df)

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# ### Now let's divide and data into features and values and perform preprocessing and build the model

# %%
X = df.drop('price',axis=1).values
Y = df['price'].values

# %%
print(X.shape)
print(Y.shape)
# Out:
# (21613, 19)
# (21613,)

# %%
# Now let's split our data into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 101)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (15129, 19)
# (6484, 19)
# (15129,)
# (6484,)

# %% [markdown]
# ### Scaling the data

# %% [markdown]
# Use MinMaxScaler as your default.
#
# Use RobustScaler if you have outliers and can handle a larger range.
#
# Use StandardScaler if you need normalized features.
#
# Use Normalizer sparingly - it normalizes rows, not columns.

# %% [markdown]
# ### Robust Scaler
# Scale features using statistics that are robust to outliers.
#
# This Scaler removes the median and scales the data according to the Interquartile Range (IQR). The IQR is the range between the 1st quartile (25th quantile) and the 3rd quartile (75th quantile).
#
# Centering and scaling happen independently on each feature (or each sample, depending on the axis argument) by computing the relevant statistics on the samples in the training set. Median and interquartile range are then stored to be used on later data using the transform method.
#
# Standardization of a dataset is a common requirement for many machine learning estimators. Typically this is done by removing the mean and scaling to unit variance. However, outliers can often influence the sample mean / variance in a negative way. In such cases, the median and the interquartile range often give better results.

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler
scaler = RobustScaler()

# %% [markdown]
# We use fit_transform() on the train data so that we learn the parameters of scaling on the train data and in the same time we scale the train data. We only use transform() on the test data because we use the scaling paramaters learned on the train data to scale the test data.
#
# This is the standart procedure to scale. You always learn your scaling parameters on the train and then use them on the test. Here is an article that explane it very well : https://sebastianraschka.com/faq/docs/scale-training-test.html

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (15129, 19)
# (6484, 19)

# %%
print(X_train.max())
print(X_train.min())
print("\n")
print(X_test.max())
print(X_test.min())
# Out:
# 2015.0
# -6.0
#
#
# 2015.0
# -3.0

# %% [markdown]
# ###### Now let's start building our model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
model = Sequential()

model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train, y=Y_train,
          validation_data=(X_test,Y_test),
          batch_size=128, epochs=500)
# Out:
# Epoch 1/500
# 119/119 [==============================] - 0s 3ms/step - loss: 423132954624.0000 - val_loss: 426919297024.0000
# Epoch 2/500
# 119/119 [==============================] - 0s 2ms/step - loss: 378156777472.0000 - val_loss: 326129418240.0000
# Epoch 3/500
# 119/119 [==============================] - 0s 2ms/step - loss: 225744289792.0000 - val_loss: 144217014272.0000
# Epoch 4/500
# 119/119 [==============================] - 0s 2ms/step - loss: 117426167808.0000 - val_loss: 87163387904.0000
# Epoch 5/500
# 119/119 [==============================] - 0s 2ms/step - loss: 75217682432.0000 - val_loss: 67342893056.0000
# Epoch 6/500
# 119/119 [==============================] - 0s 2ms/step - loss: 62517825536.0000 - val_loss: 61795221504.0000
# Epoch 7/500
# 119/119 [==============================] - 0s 2ms/step - loss: 58083237888.0000 - val_loss: 58272100352.0000
# Epoch 8/500
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

predictions = model.predict(X_test)

print(mean_squared_error(Y_test, predictions))
print(mean_absolute_error(Y_test, predictions))
print(explained_variance_score(Y_test, predictions))
# Out:
# 16247761160.271015
# 74486.63979844618
# 0.8844760574012309

# %%
plt.figure(figsize=(12,6))
plt.scatter(Y_test, predictions)
plt.plot(Y_test,Y_test,'r')

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  sqft_lot15  year_sold  month_sold
# 0      221900.0         3       1.00  ...        5650       2014          10
# 1      538000.0         3       2.25  ...        7639       2014          12
# 2      180000.0         2       1.00  ...        8062       2015           2
# 3      604000.0         4       3.00  ...        5000       2014          12
# 4      510000.0         3       2.00  ...        7503       2015           2
# ...         ...       ...        ...  ...         ...        ...         ...
# 21608  360000.0         3       2.50  ...        1509       2014           5
# 21609  400000.0         4       2.50  ...        7200       2015           2
# 21610  402101.0         2       0.75  ...        2007       2014           6
# 21611  400000.0         3       2.50  ...        1287       2015           1
# 21612  325000.0         2       0.75  ...        1357       2014          10
#
# [21613 rows x 20 columns]

# %%
single_house = df.drop('price',axis=1).iloc[0]
single_house
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year_sold        2014.0000
# month_sold         10.0000
# Name: 0, dtype: float64

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[244297.19]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year_sold  month_sold
# 0  221900.0         3        1.0  ...        5650       2014          10
#
# [1 rows x 20 columns]
